# %%
import pandas as pd
import glob
import re

# %%
import warnings
warnings.filterwarnings('ignore', category=pd.errors.DtypeWarning)

# %%
# Basic CSV reading
df15 = pd.read_csv(r'C:\Users\athar\OneDrive\Desktop\fulton_ring\fahe\education\southcarolina\sc_15.csv')
df16 = pd.read_csv(r'C:\Users\athar\OneDrive\Desktop\fulton_ring\fahe\education\southcarolina\sc_16.csv')
df17 = pd.read_csv(r'C:\Users\athar\OneDrive\Desktop\fulton_ring\fahe\education\southcarolina\sc_17.csv')
df18 = pd.read_csv(r'C:\Users\athar\OneDrive\Desktop\fulton_ring\fahe\education\southcarolina\sc_18.csv')
df19 = pd.read_csv(r'C:\Users\athar\OneDrive\Desktop\fulton_ring\fahe\education\southcarolina\sc_19.csv')
df20 = pd.read_csv(r'C:\Users\athar\OneDrive\Desktop\fulton_ring\fahe\education\southcarolina\sc_20.csv')
df21 = pd.read_csv(r'C:\Users\athar\OneDrive\Desktop\fulton_ring\fahe\education\southcarolina\sc_21.csv')
df22 = pd.read_csv(r'C:\Users\athar\OneDrive\Desktop\fulton_ring\fahe\education\southcarolina\sc_22.csv')
df23 = pd.read_csv(r'C:\Users\athar\OneDrive\Desktop\fulton_ring\fahe\education\southcarolina\sc_23.csv')

# %%
df15['year'] = 2015
df16['year'] = 2016
df17['year'] = 2017
df18['year'] = 2018
df19['year'] = 2019
df20['year'] = 2020
df21['year'] = 2021
df22['year'] = 2022
df23['year'] = 2023

# %%
# Combine them vertically
df_all = pd.concat([df15, df16, df17, df18, df19, df20, df21, df22, df23], ignore_index=True)

# %%
df_all.head()
# Out:
#            GEO_ID                               NAME  \
# 0       Geography               Geographic Area Name
# 1  0500000US45007    Anderson County, South Carolina
# 2  0500000US45021    Cherokee County, South Carolina
# 3  0500000US45045  Greenville County, South Carolina
# 4  0500000US45073      Oconee County, South Carolina
#
#                                S1501_C01_001E  \
# 0  Total!!Estimate!!Population 18 to 24 years
# 1                                       16335
# 2                                        5610
# 3                                       44645
# 4                                        6114
#
#                                       S1501_C01_001M  \
# 0  Total!!Margin of Error!!Population 18 to 24 years
# 1                                                161
# 2                                                164
# 3                                                 69
# 4                                                197
#
# ...

# %%
# Split NAME column into County and State
df_all[['County', 'State']] = df_all['NAME'].str.split(',', expand=True)
# Out:
# C:\Users\athar\AppData\Local\Temp\ipykernel_20472\61925457.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_all[['County', 'State']] = df_all['NAME'].str.split(',', expand=True)
# C:\Users\athar\AppData\Local\Temp\ipykernel_20472\61925457.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_all[['County', 'State']] = df_all['NAME'].str.split(',', expand=True)

# %%
# Clean up extra spaces
df_all['County'] = df_all['County'].str.strip()
df_all['State'] = df_all['State'].str.strip()

# %%
# Drop the original NAME column if not needed
df_all = df_all.drop(columns=['NAME'])

# %%
# Drop rows where GEO_ID is "Geography"
#df_all = df_all[df_all["GEO_ID"] != "Geography"].reset_index(drop=True)

# %%
df_all.head()
# Out:
#            GEO_ID                              S1501_C01_001E  \
# 0       Geography  Total!!Estimate!!Population 18 to 24 years
# 1  0500000US45007                                       16335
# 2  0500000US45021                                        5610
# 3  0500000US45045                                       44645
# 4  0500000US45073                                        6114
#
#                                       S1501_C01_001M  \
# 0  Total!!Margin of Error!!Population 18 to 24 years
# 1                                                161
# 2                                                164
# 3                                                 69
# 4                                                197
#
#                                  S1501_C02_001E  \
# 0  Percent!!Estimate!!Population 18 to 24 years
# 1                                           (X)
# 2                                           (X)
# 3                                           (X)
# ...

# %%
# Delete row at index 0
df_all = df_all.drop(0)

# %%
# Reset index after deletion
df_all = df_all.reset_index(drop=True)

# %%
df_all.head()
# Out:
#            GEO_ID S1501_C01_001E S1501_C01_001M S1501_C02_001E S1501_C02_001M  \
# 0  0500000US45007          16335            161            (X)            (X)
# 1  0500000US45021           5610            164            (X)            (X)
# 2  0500000US45045          44645             69            (X)            (X)
# 3  0500000US45073           6114            197            (X)            (X)
# 4  0500000US45077          22058            155            (X)            (X)
#
#   S1501_C03_001E S1501_C03_001M S1501_C04_001E S1501_C04_001M S1501_C05_001E  \
# 0           8151            114            (X)            (X)           8184
# 1           2871             58            (X)            (X)           2739
# 2          22106             51            (X)            (X)          22539
# 3           3318            121            (X)            (X)           2796
# 4          11664            102            (X)            (X)          10394
#
# ...

# %%
# Remove the word "County" from County column
df_all['County'] = df_all['County'].str.replace('County', '', regex=False).str.strip()

# %%
# Reorder columns: GEO_ID, year, County, State, then the rest
cols = df_all.columns.tolist()

# %%
# Ensure order
new_order = ['GEO_ID', 'year', 'County', 'State'] + [col for col in cols if col not in ['GEO_ID', 'year', 'County', 'State']]

# %%
df_all = df_all[new_order]

# %%
# # Remove the word "County" from County column
# df_all['County'] = df_all['County'].str.replace('County', '', regex=False).str.strip()

# # Reorder columns: GEO_ID, year, County, State, then the rest
# cols = df_all.columns.tolist()

# # Ensure order
# new_order = ['GEO_ID', 'year', 'County', 'State'] + [col for col in cols if col not in ['GEO_ID', 'year', 'County', 'State']]


# df_all = df_all[new_order]

# %%
keep = [
    "GEO_ID", "NAME", "State", "County", "year",
    "S1501_C01_001E", # Total Population
    "S1501_C02_001E", # Population Below Poverty     
    "S1501_C03_001E", # Percent Below Poverty     
    "S1501_C01_024E", # Adults with High School       
    "S1501_C03_024E", # Percent Adults with High School       
    "S1501_C01_026E", # Adults with College Degree      
    "S1501_C03_026E" # Percent Adults with College Degree
]

# %%
# Filter to the columns that exist, then rename
existing = [c for c in keep if c in df_all.columns]

# %%
renamed = {
    "S1501_C01_001E": "Total Population",
    "S1501_C02_001E": "Population Below Poverty",     
    "S1501_C03_001E": "Percent Below Poverty",      
    "S1501_C01_024E": "Adults with High School",       
    "S1501_C03_024E": "Percent Adults with High School",       
    "S1501_C01_026E": "Adults with College Degree",       
    "S1501_C03_026E": "Percent Adults with College Degree"       
}

# %%
df_out = df_all[existing].rename(columns=renamed)

# %%
keep_county = pd.read_csv(r"C:\Users\athar\OneDrive\Desktop\fulton_ring\fahe\appalachian_counties.csv")

# %%
keep_sc = keep_county[keep_county["state"] == "South Carolina"]

# %%
sc_counties = set(keep_sc["county"])

# %%
# Keep only rows in df_out where 'County' is in that list
df_out10 = df_out[df_out["County"].isin(sc_counties)]

# %%
df_out10.head()
# Out:
#            GEO_ID           State      County  year Total Population  \
# 0  0500000US45007  South Carolina    Anderson  2015            16335
# 1  0500000US45021  South Carolina    Cherokee  2015             5610
# 2  0500000US45045  South Carolina  Greenville  2015            44645
# 3  0500000US45073  South Carolina      Oconee  2015             6114
# 4  0500000US45077  South Carolina     Pickens  2015            22058
#
#   Population Below Poverty Percent Below Poverty Adults with High School  \
# 0                      (X)                  8151                   10645
# 1                      (X)                  2871                    2303
# 2                      (X)                 22106                   39642
# 3                      (X)                  3318                    5095
# 4                      (X)                 11664                    6218
#
#   Percent Adults with High School Adults with College Degree  \
# ...

# %%
df_out10.to_csv("df_10.csv", index=False)
